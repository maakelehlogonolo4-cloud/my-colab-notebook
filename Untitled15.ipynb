# %% [markdown]
# <a href="https://colab.research.google.com/github/maakelehlogonolo4-cloud/my-colab-notebook/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install packages
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.4/804.4 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 5.8 MB/s eta 0:00:00
# ...
#   Created wheel for pymongo: filename=pymongo-3.13.0-cp312-cp312-linux_x86_64.whl size=512676 sha256=9185a5aad56a4d8dbea4de81e1952e688739257b8bb7c8462f976afe7e65f50b
#   Stored in directory: /root/.cache/pip/wheels/36/d8/d4/b5636cc3c4b99684d3aa369a2d75661a06b522ed4e382a8dfa
# Successfully built pymongo
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.4.0
#     Uninstalling lxml-5.4.0:
#       Successfully uninstalled lxml-5.4.0
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/youtube-top-100-songs-2025.csv')

# %%
display(df.head())
# Out:
#                                                title  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                            fulltitle  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                          description  view_count categories  \
# 0  ROSÉ & Bruno Mars - APT.\nDownload/stream: ht...  2009014557      Music
# 1  MAYHEM OUT NOW\nhttp://ladygaga.com \n \nListe...  1324833300      Music
# 2  Listen to “BITE ME”, the new album from Reneé ...     2536628      Music
# ...

# %%
display(df.tail())
# Out:
#                                                 title  \
# 95  Ariana Grande - twilight zone (Official Lyric ...
# 96  Gracie Abrams - I Love You, I’m Sorry (Officia...
# 97  HoodTrophy Bino ft. FCG Heem - Miami (Official...
# 98               Sean Paul x INNA - Let It Talk To Me
# 99  Selena Gomez, benny blanco - How Does It Feel ...
#
#                                             fulltitle  \
# 95  Ariana Grande - twilight zone (Official Lyric ...
# 96  Gracie Abrams - I Love You, I’m Sorry (Officia...
# 97  HoodTrophy Bino ft. FCG Heem - Miami (Official...
# 98               Sean Paul x INNA - Let It Talk To Me
# 99  Selena Gomez, benny blanco - How Does It Feel ...
#
#                                           description  view_count categories  \
# 95  The official “twilight zone” official lyric vi...    18245315      Music
# 96  Listen to the new album, The Secret of Us, out...    31456772      Music
# ...

# %%
df.shape
# Out:
# (100, 13)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   100 non-null    object
#  1   fulltitle               100 non-null    object
#  2   description             100 non-null    object
#  3   view_count              100 non-null    int64
#  4   categories              100 non-null    object
#  5   tags                    85 non-null     object
#  6   duration                100 non-null    int64
#  7   duration_string         100 non-null    object
#  8   live_status             100 non-null    bool
#  9   thumbnail               100 non-null    object
#  10  channel                 100 non-null    object
#  11  channel_url             100 non-null    object
#  12  channel_follower_count  100 non-null    int64
# dtypes: bool(1), int64(3), object(9)
# memory usage: 9.6+ KB
# None

# %%
df.describe()
# Out:
#          view_count    duration  channel_follower_count
# count  1.000000e+02  100.000000            1.000000e+02
# mean   1.059103e+08  203.900000            1.612067e+07
# std    2.491132e+08   44.260592            1.980038e+07
# min    1.161000e+03  120.000000            1.000000e+00
# 25%    1.852702e+07  173.000000            6.132500e+05
# 50%    3.798224e+07  193.500000            6.320000e+06
# 75%    1.111073e+08  231.750000            2.760000e+07
# max    2.009015e+09  354.000000            7.620000e+07

# %%
display(df.describe(include= 'all'))
# Out:
#                                                    title  \
# count                                                100
# unique                                               100
# top     ROSÉ & Bruno Mars - APT. (Official Music Video)
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                                fulltitle  \
# count                                                100
# unique                                               100
# top     ROSÉ & Bruno Mars - APT. (Official Music Video)
# ...

# %%
display(df.isnull().sum())
# Out:
# title                      0
# fulltitle                  0
# description                0
# view_count                 0
# categories                 0
# tags                      15
# duration                   0
# duration_string            0
# live_status                0
# thumbnail                  0
# channel                    0
# channel_url                0
# channel_follower_count     0
# dtype: int64

# %%
display(df['categories'].value_counts())
# Out:
# categories
# Music             94
# People & Blogs     6
# Name: count, dtype: int64

# %%
display(df['tags'].value_counts())
# Out:
# tags
# Sabrina Carpenter;Island Records;Pop                                                                                                                                                                                                                                                                                                                                                                                                                                     5
# Billie Eilish;Darkroom/Interscope Records;Alternative                                                                                                                                                                                                                                                                                                                                                                                                                    3
# ...

# %%
display(df['duration'].value_counts())
# Out:
# duration
# 252    3
# 161    3
# 166    3
# 191    3
# 187    3
#       ..
# 223    1
# 157    1
# 195    1
# 259    1
# 197    1
# Name: count, Length: 69, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='categories', data=df, order=df['categories'].value_counts().index)
plt.xlabel('Count')
plt.ylabel('Categories')
plt.title('Frequency of Categories')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='duration', y='view_count', data=df)
plt.title('View_Count vs Duration')
plt.xlabel('duration')
plt.ylabel('view_count')
plt.show()
